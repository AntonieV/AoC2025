# %%
### https://adventofcode.com/2025

DAY = 5


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        rngs, ingred =  [], []
        for line in f_in.readlines():
            line = line.strip()
            if "-" in line:
                s, e = line.split("-")
                rngs.append((int(s), int(e)))
                continue
            if line != "":
                ingred.append(int(line))
        return rngs, list(filter(None, ingred))


def get_solution_1(rngs, ingred):
    fresh_ingred = []
    for item in ingred:
        for start, end in rngs:
            if item >= start and item <= end:
                fresh_ingred.append(item)
    return len(set(fresh_ingred))


def has_overlap(s1, e1, s2, e2):
    is_overlap = e1 >= s2 and e1 <= e2 and s1 <= s2
    is_included = s1 <= s2 and e1 >= e2
    return is_overlap or is_included
 
    
# def merge_overlaps(rngs):
#     rngs = sorted(list(set(rngs)))
# #     print(rngs)
#     pairs = list(combinations(rngs,2))  #list(zip(rngs[::2], rngs[1::2]))
#     prev_len = -1
    
#     while prev_len != len(rngs):
#         prev_len = len(rngs) 
#         pairs = list(combinations(rngs,2))
#         print(list(pairs))
#         print(rngs)
#         for pair in pairs:      
#             pair = sorted(pair)
#             s1, e1 = pair[0]
#             s2, e2 = pair[1]
# #             print(print(s1, e1, s2, e2, has_overlaping_intervals(s1, e1, s2, e2)))
#             if has_overlap(s1, e1, s2, e2):
#                 rngs.append((s1, e2))
#                 rngs.remove((s1, e1))
#                 rngs.remove((s2, e2))        
#                 print(rngs)
#                 break
# #         print(prev_len, len(rngs))
#     return rngs

    

def merge_overlaps(rngs):
    rngs = sorted(list(set(rngs)))
    print(rngs)
    prev_len = -1
    while prev_len != len(rngs):        
        prev_len = len(rngs)
        for idx, rng in enumerate(rngs):
            if idx + 1 < len(rngs):
                s1, e1 = rng
                s2, e2 = rngs[idx + 1]
                print(print(s1, e1, s2, e2, has_overlap(s1, e1, s2, e2)))
                if has_overlap(s1, e1, s2, e2):
                    rngs.append((s1, e2))
                    rngs.remove((s1, e1))
                    rngs.remove((s2, e2))  
                    rngs = sorted(list(set(rngs)))
                    print(rngs)
                    break
#         print(prev_len, len(rngs))
    return rngs


    
def get_solution_2(rngs):
    rngs = merge_overlaps(rngs)
    print(rngs)
    print("FINAL:", rngs)
    num_ingred = 0
    for start, end in rngs:
        num_ingred += len(list(set(range(start, end + 1))))
    return num_ingred



file = f"../data/test_day_{DAY}.txt"
file = f"../data/day_{DAY}.txt"


ranges, ingredients = read_file(file)

solution_1 = get_solution_1(ranges, ingredients)
print(f"Day {DAY} - Solution 1:", solution_1)

# TODO: does not works yet, needs too much mem
# solution_2 = get_solution_2(ranges)
# print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 5 - Solution 1: 529

# %%
### https://adventofcode.com/2025

DAY = 6


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input(_data):
    pass


def get_solution_1(_data):
    pass
        
    
def get_solution_2(_data):
    pass



file = f"../data/test_day_{DAY}.txt"
file = f"../data/day_{DAY}.txt"


data = read_file(file)
data = parse_input(data)

solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 6 - Solution 1: None
# Day 6 - Solution 2: None

# %%
### https://adventofcode.com/2025

DAY = 7


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input(_data):
    pass


def get_solution_1(_data):
    pass
        
    
def get_solution_2(_data):
    pass



file = f"../data/test_day_{DAY}.txt"
file = f"../data/day_{DAY}.txt"


data = read_file(file)
data = parse_input(data)

solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 7 - Solution 1: None
# Day 7 - Solution 2: None

# %%
### https://adventofcode.com/2025

DAY = 8


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input(_data):
    pass


def get_solution_1(_data):
    pass
        
    
def get_solution_2(_data):
    pass



file = f"../data/test_day_{DAY}.txt"
file = f"../data/day_{DAY}.txt"


data = read_file(file)
data = parse_input(data)

solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 8 - Solution 1: None
# Day 8 - Solution 2: None
